# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import load_diabetes

dataset = load_diabetes(return_X_y=False, as_frame=True, scaled=True)

dataset.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# s1-s6: tc, ldl, hdl, tch, ltg, glu

# %%
df = dataset.data
target = dataset.target

df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'bp'}>, <Axes: title={'center': 's1'}>,
#         <Axes: title={'center': 's2'}>],
#        [<Axes: title={'center': 's3'}>, <Axes: title={'center': 's4'}>,
#         <Axes: title={'center': 's5'}>],
#        [<Axes: title={'center': 's6'}>, <Axes: >, <Axes: >]], dtype=object)

# %%
target.hist()
# Out:
# <Axes: >

# %% [markdown]
# df = pd.get_dummies(df, drop_first=True, columns=["sex"])
#
# scaler = StandardScaler()
#
# scaled_df = scaler.fit_transform(df)
#
#
# fanns redan i datasetet.

# %%
df = pd.get_dummies(df, columns=['sex'], drop_first=True)
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoLars, LassoLarsCV, ElasticNetCV

linear = LinearRegression()
lasso = Lasso()
ridge = Ridge()
lars_a1 = LassoLars(alpha=0.5)
lars_a2 = LassoLars(alpha=0.1)
lars = LassoLarsCV()
elast = ElasticNetCV()

# %%
linear.fit(X_train, y_train)
lasso.fit(X_train, y_train)
ridge.fit(X_train, y_train)
lars_a1.fit(X_train, y_train)
lars_a2.fit(X_train, y_train)
lars.fit(X_train, y_train)
elast.fit(X_train, y_train)
# Out:
# ElasticNetCV()

# %%
from sklearn.metrics import root_mean_squared_error

y_linear = linear.predict(X_test)
y_lasso = lasso.predict(X_test)
y_ridge = ridge.predict(X_test)
y_lars_a1 = lars_a1.predict(X_test)
y_lars_a2 = lars_a2.predict(X_test)
y_lars = lars.predict(X_test)
y_elast = elast.predict(X_test)

# %%
print("Linear:", root_mean_squared_error(y_test, y_linear))
print("Lasso:", root_mean_squared_error(y_test, y_lasso))
print("Ridge:", root_mean_squared_error(y_test, y_ridge))
print("Lars alpha=0.5:", root_mean_squared_error(y_test, y_lars_a1))
print("Lars alpha=0.1:", root_mean_squared_error(y_test, y_lars_a2))
print("LarsCV:", root_mean_squared_error(y_test, y_lars))
print("ElasticNetCV:", root_mean_squared_error(y_test, y_elast))
# Out:
# Linear: 51.0493360736001
# Lasso: 58.786550385259844
# Ridge: 54.89325815485399
# Lars alpha=0.5: 53.881498267721355
# Lars alpha=0.1: 51.249980143183116
# LarsCV: 51.041932600248394
# ElasticNetCV: 53.734808589147164

# %%
lars.alpha_
# Out:
# np.float64(0.05893093899202474)

# %%
elast.l1_ratio_
# Out:
# np.float64(0.5)

# %%
target.describe()
# Out:
# count    442.000000
# mean     152.133484
# std       77.093005
# min       25.000000
# 25%       87.000000
# 50%      140.500000
# 75%      211.500000
# max      346.000000
# Name: target, dtype: float64

# %%
linear.coef_
# Out:
# array([  18.78369134,  504.7617681 ,  354.20858513, -865.87194644,
#         537.50831835,  156.84902898,  176.08548965,  804.47141539,
#          37.12064893,  -21.37838085])

# %%
linear.feature_names_in_
# Out:
# array(['age', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'sex_0.05068011873981862'], dtype=object)
